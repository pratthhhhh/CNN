# %%
import argparse
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable
import torch.nn.functional as F
import numpy as np
import time
import math
from PIL import Image
import matplotlib.pyplot as plt

# %%
from models import *
from dataloader import KITTILoader as DA
from dataloader import preprocess

# %%
# GPU smoke test
import torch
from models.stackhourglass import PSMNet as StackPSM

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

model = StackPSM(192).to(device)
model.eval()

B, C, H, W = 1, 3, 256, 512  # reduce H,W if you have limited GPU memory
left = torch.randn(B, C, H, W, device=device)
right = torch.randn(B, C, H, W, device=device)

try:
    with torch.no_grad():
        out = model(left, right)
    print('Forward pass successful. Output type:', type(out))
    if isinstance(out, torch.Tensor):
        print('Output shape:', out.shape)
    elif isinstance(out, (list, tuple)):
        print('Tuple lengths/shapes:', [x.shape if isinstance(x, torch.Tensor) else str(type(x)) for x in out])
except Exception as e:
    print('Forward failed:', type(e).__name__, e)
# Out:
# Using device: cuda
# Forward pass successful. Output type: <class 'torch.Tensor'>
# Output shape: torch.Size([1, 1, 256, 512])

# %%
# Dataloader
import os
import torch
import torch.utils.data as data
import torchvision.transforms as transforms
from PIL import Image
import numpy as np
import random
from dataloader import preprocess

IMG_EXTENSIONS = [
    '.jpg', '.JPG', '.jpeg', '.JPEG',
    '.png', '.PNG', '.ppm', '.PPM', '.bmp', '.BMP',
]

def is_image_file(filename):
    return any(filename.endswith(extension) for extension in IMG_EXTENSIONS)

def default_loader(path):
    return Image.open(path).convert('RGB')

def disparity_loader(path):
    return Image.open(path)


class MyImageFloder(data.Dataset):
    def __init__(self, left, right, left_disparity, training, loader=default_loader, dploader=disparity_loader):
        self.left = left
        self.right = right
        self.disp_L = left_disparity
        self.loader = loader
        self.dploader = dploader
        self.training = training

    def __getitem__(self, index):
        left = self.left[index]
        right = self.right[index]
        disp_L = self.disp_L[index]

        left_img = self.loader(left)
        right_img = self.loader(right)
        dataL = self.dploader(disp_L)

        if self.training:
            w, h = left_img.size
            th, tw = 256, 512

            x1 = random.randint(0, w - tw)
            y1 = random.randint(0, h - th)

            left_img = left_img.crop((x1, y1, x1 + tw, y1 + th))
            right_img = right_img.crop((x1, y1, x1 + tw, y1 + th))

            dataL = np.ascontiguousarray(dataL, dtype=np.float32) / 256
            dataL = dataL[y1:y1 + th, x1:x1 + tw]

            processed = preprocess.get_transform(augment=False)
            left_img = processed(left_img)
            right_img = processed(right_img)

            return left_img, right_img, dataL
        else:
            w, h = left_img.size
            left_img = left_img.crop((w - 1232, h - 368, w, h))
            right_img = right_img.crop((w - 1232, h - 368, w, h))
            dataL = dataL.crop((w - 1232, h - 368, w, h))
            dataL = np.ascontiguousarray(dataL, dtype=np.float32) / 256

            processed = preprocess.get_transform(augment=False)
            left_img = processed(left_img)
            right_img = processed(right_img)

            return left_img, right_img, dataL

    def __len__(self):
        return len(self.left)

# %%
datapath = '/mnt/c/Users/prath/OneDrive/Desktop/Assignments/Thesis/Dataset/CARLA'

left_image_path = os.path.join(datapath, 'left')
right_image_path = os.path.join(datapath, 'right')
disparity_path = os.path.join(datapath, 'disparity')

left_images = sorted([os.path.join(left_image_path, img) for img in os.listdir(left_image_path) if is_image_file(img)])
right_images = sorted([os.path.join(right_image_path, img) for img in os.listdir(right_image_path) if is_image_file(img)])
disparity_images = sorted([os.path.join(disparity_path, img) for img in os.listdir(disparity_path) if is_image_file(img)])

# Train/test split 
train_size = int(0.8 * len(left_images))
val_size = len(left_images) - train_size

combined = list(zip(left_images, right_images, disparity_images))
random.shuffle(combined)
left_images, right_images, disparity_images = zip(*combined)

train_left_img = left_images[:train_size]
train_right_img = right_images[:train_size]
train_left_disp = disparity_images[:train_size]

test_left_img = left_images[train_size:]
test_right_img = right_images[train_size:]
test_left_disp = disparity_images[train_size:]

# DataLoader instances
TrainImgLoader = torch.utils.data.DataLoader(
    MyImageFloder(train_left_img, train_right_img, train_left_disp, True),
    batch_size=4, shuffle=True, num_workers=4, drop_last=False)

TestImgLoader = torch.utils.data.DataLoader(
    MyImageFloder(test_left_img, test_right_img, test_left_disp, False),
    batch_size=2, shuffle=False, num_workers=2, drop_last=False)

# %%
# Testing the test DataLoader
import matplotlib.pyplot as plt

imgL, imgR, disp_L = next(iter(TestImgLoader))

num_samples = min(2, imgL.size(0))
plt.figure(figsize=(12, 2 * num_samples))

for i in range(num_samples):
    # Left Image
    plt.subplot(num_samples, 3, 3*i + 1)
    plt.imshow(imgL[i].permute(1, 2, 0).numpy())
    plt.title("Left Image")
    plt.axis("off")
    
    # Right Image
    plt.subplot(num_samples, 3, 3*i + 2)
    plt.imshow(imgR[i].permute(1, 2, 0).numpy())
    plt.title("Right Image")
    plt.axis("off")
    
    # Disparity Map
    plt.subplot(num_samples, 3, 3*i + 3)
    plt.imshow(disp_L[i].squeeze().numpy(), cmap="plasma")
    plt.title("Ground Truth Disparity")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].

# %%
# Model and training parameters
maxdisp = 192
epochs = 5
learning_rate = 0.001
model_name = 'stackhourglass'
cuda_available = torch.cuda.is_available()
loadmodel = "best_checkpoint.tar"
savemodel = './'

if model_name == 'stackhourglass':
    model = stackhourglass(maxdisp)
elif model_name == 'basic':
    model = basic(maxdisp)
else:
    raise ValueError('Model not recognized')

if cuda_available:
    model = nn.DataParallel(model)
    model.cuda()

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999))

start_epoch = 1
best_val_loss = float('inf')

if loadmodel is not None and os.path.exists(loadmodel):
    print(f"Loading checkpoint from {loadmodel}")
    state_dict = torch.load(loadmodel)
    model.load_state_dict(state_dict['state_dict'])
    optimizer.load_state_dict(state_dict['optimizer'])
    start_epoch = state_dict['epoch'] + 1
    best_val_loss = state_dict['test_loss']
    print(f"Resuming training from epoch {start_epoch}")

def train(imgL, imgR, disp_L):
    model.train()
    imgL = Variable(torch.FloatTensor(imgL))
    imgR = Variable(torch.FloatTensor(imgR))
    disp_L = Variable(torch.FloatTensor(disp_L))

    if cuda_available:
        imgL, imgR, disp_true = imgL.cuda(), imgR.cuda(), disp_L.cuda()

    mask = (disp_true > 0)
    mask.detach_()

    optimizer.zero_grad()

    if model_name == 'stackhourglass':
        output1, output2, output3 = model(imgL, imgR)
        output1 = torch.squeeze(output1, 1)
        output2 = torch.squeeze(output2, 1)
        output3 = torch.squeeze(output3, 1)
        loss = 0.5 * F.smooth_l1_loss(output1[mask], disp_true[mask], size_average=True) + \
               0.7 * F.smooth_l1_loss(output2[mask], disp_true[mask], size_average=True) + \
               F.smooth_l1_loss(output3[mask], disp_true[mask], size_average=True)
    elif model_name == 'basic':
        output = model(imgL, imgR)
        output = torch.squeeze(output, 1)
        loss = F.smooth_l1_loss(output[mask], disp_true[mask], size_average=True)

    loss.backward()
    optimizer.step()

    return loss.item()


def test(imgL, imgR, disp_true):
    model.eval()

    imgL = Variable(torch.FloatTensor(imgL))
    imgR = Variable(torch.FloatTensor(imgR))
    
    if cuda_available:
        imgL, imgR = imgL.cuda(), imgR.cuda()

    with torch.no_grad():
        output3 = model(imgL,imgR)

    pred_disp = output3.data.cpu()
    pred_disp = torch.squeeze(pred_disp,1)

    disp_true = disp_true.cpu()
    mask = (disp_true > 0)
    loss = torch.mean(torch.abs(pred_disp[mask] - disp_true[mask]))

    return loss
# Out:
# Loading checkpoint from best_checkpoint.tar
# Resuming training from epoch 4

# %%
# TRAINING LOOP FOR 3 EPOCHS
start_full_time = time.time()

for epoch in range(start_epoch, epochs + 1):
    total_train_loss = 0
    total_test_loss = 0

    ## Training ##
    for batch_idx, (imgL_crop, imgR_crop, disp_crop_L) in enumerate(TrainImgLoader):
        start_time = time.time()
        loss = train(imgL_crop, imgR_crop, disp_crop_L)
        print(f'Epoch {epoch}, Iter {batch_idx} training loss = {loss:.3f}, time = {(time.time() - start_time):.2f}')
        total_train_loss += loss
    print(f'epoch {epoch} total training loss = {total_train_loss / len(TrainImgLoader):.3f}')

    ## Validation ##
    for batch_idx, (imgL, imgR, disp_L) in enumerate(TestImgLoader):
        test_loss = test(imgL, imgR, disp_L)
        print(f'Iter {batch_idx} validation loss = {test_loss:.3f}')
        total_test_loss += test_loss
    
    avg_test_loss = total_test_loss / len(TestImgLoader)
    print(f'epoch {epoch} total validation loss = {avg_test_loss:.3f}')

    # Saving best checkpoint
    if avg_test_loss < best_val_loss:
        best_val_loss = avg_test_loss
        savefilename = os.path.join(savemodel, 'best_checkpoint5.tar')
        torch.save({
            'epoch': epoch,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(), # <-- Save optimizer state
            'train_loss': total_train_loss / len(TrainImgLoader),
            'test_loss': avg_test_loss,
        }, savefilename)
        print(f"Saved best model at epoch {epoch} with validation loss {avg_test_loss:.3f}")

print('Full training time = %.2f HR' % ((time.time() - start_full_time) / 3600))
# Out:
# Epoch 1, Iter 0 training loss = 179.545, time = 27.11
# Epoch 1, Iter 1 training loss = 86.337, time = 26.99
# Epoch 1, Iter 2 training loss = 44.707, time = 26.94
# Epoch 1, Iter 3 training loss = 27.662, time = 26.81
# Epoch 1, Iter 4 training loss = 38.831, time = 26.58
# Epoch 1, Iter 5 training loss = 25.139, time = 26.65
# Epoch 1, Iter 6 training loss = 34.930, time = 26.95
# Epoch 1, Iter 7 training loss = 36.502, time = 27.02
# Epoch 1, Iter 8 training loss = 31.944, time = 27.63
# Epoch 1, Iter 9 training loss = 30.056, time = 26.08
# Epoch 1, Iter 10 training loss = 42.274, time = 26.84
# Epoch 1, Iter 11 training loss = 26.838, time = 25.56
# Epoch 1, Iter 12 training loss = 39.151, time = 22.96
# Epoch 1, Iter 218 training loss = 30.010, time = 26.65
# Epoch 1, Iter 219 training loss = 30.775, time = 25.75
# Epoch 1, Iter 220 training loss = 34.748, time = 26.54
# Epoch 1, Iter 221 training loss = 43.499, time = 27.41
# Epoch 1, Iter 222 training loss = 31.477, time = 26.67
# Epoch 1, Iter 223 training loss = 36.343, time = 26.21
# Epoch 1, Iter 224 training loss = 40.599, time = 23.11
# Epoch 1, Iter 225 training loss = 30.789, time = 26.09
# Epoch 1, Iter 226 training loss = 28.689, time = 26.46
# Epoch 1, Iter 227 training loss = 24.565, time = 0.82
# epoch 1 total training loss = 36.545
# Iter 0 validation loss = 21.072
# Iter 1 validation loss = 20.090
# Iter 2 validation loss = 30.902
# Iter 3 validation loss = 20.941
# Iter 4 validation loss = 24.825
# Iter 5 validation loss = 24.298
# Iter 6 validation loss = 24.521
# Iter 7 validation loss = 25.533
# Iter 8 validation loss = 16.118
# Iter 9 validation loss = 27.140
# Iter 10 validation loss = 24.487
# Iter 11 validation loss = 26.406
# Iter 12 validation loss = 25.323
# Iter 13 validation loss = 15.438
# Iter 14 validation loss = 25.175
# Iter 15 validation loss = 24.227
# Iter 16 validation loss = 21.388
# Iter 17 validation loss = 28.135
# Iter 18 validation loss = 24.960
# Iter 19 validation loss = 21.806
# Iter 20 validation loss = 28.614
# Iter 21 validation loss = 20.295
# Iter 22 validation loss = 24.034
# Iter 23 validation loss = 22.683
# Iter 24 validation loss = 27.386
# Iter 25 validation loss = 25.528
# Iter 26 validation loss = 22.327
# Iter 27 validation loss = 22.943
# Iter 28 validation loss = 18.223
# Iter 29 validation loss = 26.700
# Iter 30 validation loss = 22.238
# Iter 31 validation loss = 24.542
# Iter 32 validation loss = 26.307
# Iter 33 validation loss = 26.605
# Iter 34 validation loss = 24.700
# Iter 35 validation loss = 27.955
# Iter 36 validation loss = 30.370
# Iter 37 validation loss = 28.017
# Iter 38 validation loss = 27.400
# Iter 39 validation loss = 24.511
# Iter 40 validation loss = 17.199
# Iter 41 validation loss = 16.583
# Iter 42 validation loss = 25.561
# Iter 43 validation loss = 26.187
# Iter 44 validation loss = 26.267
# Iter 45 validation loss = 28.469
# Iter 46 validation loss = 23.876
# Iter 47 validation loss = 22.782
# Iter 48 validation loss = 24.020
# Iter 49 validation loss = 21.212
# Iter 50 validation loss = 21.171
# Iter 51 validation loss = 26.038
# Iter 52 validation loss = 19.567
# Iter 53 validation loss = 18.659
# Iter 54 validation loss = 29.821
# Iter 55 validation loss = 27.195
# Iter 56 validation loss = 32.817
# Iter 57 validation loss = 19.561
# Iter 58 validation loss = 29.064
# Iter 59 validation loss = 24.756
# Iter 60 validation loss = 19.839
# Iter 61 validation loss = 17.362
# Iter 62 validation loss = 24.647
# Iter 63 validation loss = 25.418
# Iter 64 validation loss = 28.547
# Iter 65 validation loss = 27.964
# Iter 66 validation loss = 26.244
# Iter 67 validation loss = 21.927
# Iter 68 validation loss = 19.263
# Iter 69 validation loss = 21.228
# Iter 70 validation loss = 26.964
# Iter 71 validation loss = 14.928
# Iter 72 validation loss = 19.574
# Iter 73 validation loss = 23.157
# Iter 74 validation loss = 25.290
# Iter 75 validation loss = 22.124
# Iter 76 validation loss = 31.231
# Iter 77 validation loss = 25.366
# Iter 78 validation loss = 23.576
# Iter 79 validation loss = 20.413
# Iter 80 validation loss = 24.031
# Iter 81 validation loss = 28.675
# Iter 82 validation loss = 23.972
# Iter 83 validation loss = 25.924
# Iter 84 validation loss = 26.761
# Iter 85 validation loss = 22.927
# Iter 86 validation loss = 23.592
# Iter 87 validation loss = 21.157
# Iter 88 validation loss = 24.367
# Iter 89 validation loss = 20.504
# Iter 90 validation loss = 17.576
# Iter 91 validation loss = 24.565
# Iter 92 validation loss = 24.729
# Iter 93 validation loss = 20.299
# Iter 94 validation loss = 25.603
# Iter 95 validation loss = 23.435
# Iter 96 validation loss = 21.723
# Iter 97 validation loss = 24.810
# Iter 98 validation loss = 28.181
# Iter 99 validation loss = 28.524
# Iter 100 validation loss = 24.555
# Iter 101 validation loss = 22.535
# Iter 102 validation loss = 24.448
# Iter 103 validation loss = 24.688
# Iter 104 validation loss = 23.294
# Iter 105 validation loss = 24.846
# Iter 106 validation loss = 23.280
# Iter 107 validation loss = 22.353
# Iter 108 validation loss = 18.432
# Iter 109 validation loss = 26.360
# Iter 110 validation loss = 20.070
# Iter 111 validation loss = 24.837
# Iter 112 validation loss = 21.362
# Iter 113 validation loss = 24.616
# epoch 1 total validation loss = 23.922
# Saved best model at epoch 1 with validation loss 23.922
# Epoch 2, Iter 0 training loss = 39.706, time = 25.66
# Epoch 2, Iter 1 training loss = 36.474, time = 26.88
# Epoch 2, Iter 2 training loss = 22.329, time = 26.79
# Epoch 2, Iter 3 training loss = 36.146, time = 26.67
# Epoch 2, Iter 4 training loss = 35.502, time = 26.57
# Epoch 2, Iter 5 training loss = 36.182, time = 25.87
# Epoch 2, Iter 6 training loss = 32.365, time = 26.73
# Epoch 2, Iter 7 training loss = 36.201, time = 26.61
# Epoch 2, Iter 8 training loss = 25.987, time = 22.79
# Epoch 2, Iter 9 training loss = 28.956, time = 21.98
# Epoch 2, Iter 10 training loss = 47.943, time = 23.02
# Epoch 2, Iter 11 training loss = 29.794, time = 22.76
# Epoch 2, Iter 12 training loss = 38.696, time = 22.80
# Epoch 2, Iter 13 training loss = 48.550, time = 21.94
# Epoch 2, Iter 14 training loss = 34.030, time = 22.85
# Epoch 2, Iter 15 training loss = 38.998, time = 22.84
# Epoch 2, Iter 16 training loss = 39.842, time = 21.96
# Epoch 2, Iter 17 training loss = 51.025, time = 22.81
# Epoch 2, Iter 18 training loss = 32.511, time = 22.84
# Epoch 2, Iter 19 training loss = 32.241, time = 21.94
# Epoch 2, Iter 20 training loss = 40.439, time = 22.72
# Epoch 2, Iter 21 training loss = 31.070, time = 22.87
# Epoch 2, Iter 22 training loss = 31.337, time = 21.91
# Epoch 2, Iter 23 training loss = 38.430, time = 22.62
# Epoch 2, Iter 24 training loss = 45.787, time = 23.07
# Iter 2 validation loss = 27.775
# Iter 3 validation loss = 19.130
# Iter 4 validation loss = 22.579
# Iter 5 validation loss = 21.154
# Iter 6 validation loss = 23.135
# Iter 7 validation loss = 22.995
# Iter 8 validation loss = 13.990
# Iter 9 validation loss = 24.421
# Iter 10 validation loss = 22.387
# Iter 11 validation loss = 24.530
# Iter 12 validation loss = 22.560
# Iter 13 validation loss = 13.044
# Iter 14 validation loss = 23.851
# Iter 15 validation loss = 22.684
# Iter 16 validation loss = 19.325
# Iter 17 validation loss = 25.954
# Iter 18 validation loss = 23.411
# Iter 19 validation loss = 20.131
# Iter 20 validation loss = 26.211
# Iter 21 validation loss = 18.734
# Iter 22 validation loss = 22.316
# Iter 23 validation loss = 19.910
# Iter 24 validation loss = 24.873
# Iter 25 validation loss = 23.147
# Iter 26 validation loss = 19.864
# Iter 27 validation loss = 20.998
# Iter 28 validation loss = 16.964
# Iter 29 validation loss = 24.797
# Iter 30 validation loss = 20.597
# Iter 31 validation loss = 22.517
# Iter 32 validation loss = 24.252
# Iter 33 validation loss = 24.238
# Iter 34 validation loss = 22.359
# Iter 35 validation loss = 25.889
# Iter 36 validation loss = 27.522
# Iter 37 validation loss = 25.310
# Iter 38 validation loss = 25.623
# Iter 39 validation loss = 22.153
# Iter 40 validation loss = 14.233
# Iter 41 validation loss = 13.917
# Iter 42 validation loss = 24.011
# Iter 43 validation loss = 24.439
# Iter 44 validation loss = 23.428
# Iter 45 validation loss = 25.488
# Iter 46 validation loss = 21.012
# Iter 47 validation loss = 21.738
# Iter 48 validation loss = 21.513
# Iter 49 validation loss = 19.020
# Iter 50 validation loss = 19.397
# Iter 51 validation loss = 24.846
# Iter 52 validation loss = 17.790
# Iter 53 validation loss = 16.407
# Iter 54 validation loss = 28.573
# Iter 55 validation loss = 24.870
# Iter 56 validation loss = 30.175
# Iter 57 validation loss = 17.595
# Iter 58 validation loss = 26.502
# Iter 59 validation loss = 22.920
# Iter 60 validation loss = 17.138
# Iter 61 validation loss = 15.984
# Iter 62 validation loss = 22.133
# Iter 63 validation loss = 23.528
# Iter 64 validation loss = 25.920
# Iter 65 validation loss = 26.295
# Iter 66 validation loss = 23.509
# Iter 67 validation loss = 20.330
# Iter 68 validation loss = 17.460
# Iter 69 validation loss = 19.271
# Iter 70 validation loss = 24.571
# Iter 71 validation loss = 12.285
# Iter 72 validation loss = 17.422
# Iter 73 validation loss = 21.524
# Iter 74 validation loss = 23.040
# Iter 75 validation loss = 20.356
# Iter 76 validation loss = 28.212
# Iter 77 validation loss = 23.235
# Iter 78 validation loss = 20.744
# Iter 79 validation loss = 18.432
# Iter 80 validation loss = 22.594
# Iter 81 validation loss = 26.030
# Iter 82 validation loss = 21.164
# Iter 83 validation loss = 23.599
# Iter 84 validation loss = 23.870
# Iter 85 validation loss = 20.965
# Iter 86 validation loss = 21.944
# Iter 87 validation loss = 19.465
# Iter 88 validation loss = 21.661
# Iter 89 validation loss = 17.998
# Iter 90 validation loss = 16.955
# Iter 91 validation loss = 22.387
# Iter 92 validation loss = 22.838
# Epoch 3, Iter 191 training loss = 14.824, time = 28.38
# Epoch 3, Iter 192 training loss = 24.419, time = 28.16
# Epoch 3, Iter 193 training loss = 22.559, time = 28.42
# Epoch 3, Iter 194 training loss = 18.074, time = 28.39
# Epoch 3, Iter 195 training loss = 22.427, time = 28.18
# Epoch 3, Iter 196 training loss = 19.673, time = 26.63
# Epoch 3, Iter 197 training loss = 20.567, time = 27.90
# Epoch 3, Iter 198 training loss = 18.344, time = 25.53
# Epoch 3, Iter 199 training loss = 23.214, time = 23.37
# Epoch 3, Iter 200 training loss = 22.858, time = 21.24
# Epoch 3, Iter 201 training loss = 17.041, time = 23.37
# Epoch 3, Iter 202 training loss = 13.339, time = 23.15
# Epoch 3, Iter 203 training loss = 18.745, time = 21.58
# Epoch 3, Iter 204 training loss = 15.593, time = 23.14
# Epoch 3, Iter 205 training loss = 17.713, time = 23.11
# Epoch 3, Iter 206 training loss = 14.395, time = 21.55
# Epoch 3, Iter 207 training loss = 21.241, time = 23.09
# Epoch 3, Iter 208 training loss = 20.523, time = 23.13
# Epoch 3, Iter 209 training loss = 22.074, time = 21.55
# Epoch 3, Iter 210 training loss = 22.250, time = 23.11
# Epoch 3, Iter 211 training loss = 13.544, time = 23.12
# Epoch 3, Iter 212 training loss = 19.573, time = 21.57
# Epoch 3, Iter 213 training loss = 32.628, time = 23.14
# Epoch 3, Iter 214 training loss = 19.561, time = 23.12
# Epoch 3, Iter 215 training loss = 16.842, time = 21.54
# Epoch 3, Iter 216 training loss = 19.196, time = 23.07
# Epoch 3, Iter 217 training loss = 20.198, time = 23.12
# Epoch 3, Iter 218 training loss = 18.251, time = 21.40
# Epoch 3, Iter 219 training loss = 15.785, time = 23.59
# Epoch 3, Iter 220 training loss = 15.425, time = 22.84
# Epoch 3, Iter 221 training loss = 11.745, time = 21.50
# Epoch 3, Iter 222 training loss = 21.611, time = 23.12
# Epoch 3, Iter 223 training loss = 18.169, time = 23.18
# Epoch 3, Iter 224 training loss = 20.916, time = 21.54
# Epoch 3, Iter 225 training loss = 20.394, time = 23.91
# Epoch 3, Iter 226 training loss = 12.524, time = 21.45
# Epoch 3, Iter 227 training loss = 15.979, time = 0.69
# epoch 3 total training loss = 22.258
# Iter 0 validation loss = 9.284
# Iter 1 validation loss = 9.401
# Iter 2 validation loss = 15.970
# Iter 3 validation loss = 10.877
# Iter 4 validation loss = 13.391
# Iter 5 validation loss = 10.523
# Iter 6 validation loss = 10.139
# Iter 7 validation loss = 12.814
# Iter 8 validation loss = 10.852
# Iter 9 validation loss = 9.823
# Iter 10 validation loss = 9.320
# Iter 11 validation loss = 10.816
# Iter 12 validation loss = 10.748
# Iter 13 validation loss = 8.169
# Iter 14 validation loss = 10.393
# Iter 15 validation loss = 9.610
# Iter 16 validation loss = 9.110
# Iter 17 validation loss = 15.541
# Iter 18 validation loss = 9.499
# Iter 19 validation loss = 9.267
# Iter 20 validation loss = 13.140
# Iter 21 validation loss = 10.732
# Iter 22 validation loss = 9.887
# Iter 23 validation loss = 8.966
# Iter 24 validation loss = 11.663
# Iter 25 validation loss = 9.530
# Iter 26 validation loss = 10.230
# Iter 27 validation loss = 10.268
# Iter 28 validation loss = 8.371
# Iter 29 validation loss = 12.494
# Iter 30 validation loss = 11.226
# Iter 31 validation loss = 9.455
# Iter 32 validation loss = 10.926
# Iter 33 validation loss = 10.397
# Iter 34 validation loss = 9.881
# Iter 35 validation loss = 11.856
# Iter 36 validation loss = 11.949
# Iter 37 validation loss = 11.451
# Iter 38 validation loss = 12.310
# Iter 39 validation loss = 11.729
# Iter 40 validation loss = 7.113
# Iter 41 validation loss = 7.884
# Iter 42 validation loss = 13.689
# Iter 43 validation loss = 10.282
# Iter 44 validation loss = 10.690
# Iter 45 validation loss = 10.523
# Iter 46 validation loss = 10.181
# Iter 47 validation loss = 12.087
# Iter 48 validation loss = 8.810
# Iter 49 validation loss = 8.501
# Iter 50 validation loss = 9.830
# Iter 51 validation loss = 11.940
# Iter 52 validation loss = 7.588
# Iter 53 validation loss = 8.622
# Iter 54 validation loss = 13.566
# Iter 55 validation loss = 10.293
# Iter 56 validation loss = 16.816
# Iter 57 validation loss = 8.471
# Iter 58 validation loss = 11.773
# Iter 59 validation loss = 9.942
# Iter 60 validation loss = 12.651
# Iter 61 validation loss = 8.868
# Iter 62 validation loss = 10.449
# Iter 63 validation loss = 11.367
# Iter 64 validation loss = 12.311
# Iter 65 validation loss = 12.224
# Iter 66 validation loss = 9.718
# Iter 67 validation loss = 9.876
# Iter 68 validation loss = 8.733
# Iter 69 validation loss = 8.997
# Iter 70 validation loss = 10.214
# Iter 71 validation loss = 11.146
# Iter 72 validation loss = 9.078
# Iter 73 validation loss = 9.145
# Iter 74 validation loss = 9.257
# Iter 75 validation loss = 8.243
# Iter 76 validation loss = 12.807
# Iter 77 validation loss = 10.492
# Iter 78 validation loss = 9.669
# Iter 79 validation loss = 8.487
# Iter 80 validation loss = 9.339
# Iter 81 validation loss = 11.833
# Iter 82 validation loss = 9.563
# Iter 83 validation loss = 10.104
# Iter 84 validation loss = 10.842
# Iter 85 validation loss = 9.791
# Iter 86 validation loss = 9.213
# Iter 87 validation loss = 7.687
# Iter 88 validation loss = 8.571
# Iter 89 validation loss = 7.855
# Iter 90 validation loss = 6.244
# Iter 91 validation loss = 9.851
# Iter 92 validation loss = 10.377
# Iter 93 validation loss = 8.063
# Iter 94 validation loss = 10.039
# Iter 95 validation loss = 10.937
# Iter 96 validation loss = 8.414
# Iter 97 validation loss = 11.770
# Iter 98 validation loss = 11.323
# Iter 99 validation loss = 12.955
# Iter 100 validation loss = 9.836
# Iter 101 validation loss = 9.440
# Iter 102 validation loss = 9.189
# Iter 103 validation loss = 11.570
# Iter 104 validation loss = 11.469
# Iter 105 validation loss = 9.221
# Iter 106 validation loss = 12.681
# Iter 107 validation loss = 10.848
# Iter 108 validation loss = 10.913
# Iter 109 validation loss = 9.504
# Iter 110 validation loss = 8.121
# Iter 111 validation loss = 9.432
# Iter 112 validation loss = 12.459
# Iter 113 validation loss = 9.532
# epoch 3 total validation loss = 10.380
# Saved best model at epoch 3 with validation loss 10.380
# Full training time = 6.08 HR

# %%
# TESTING FOR 3 EPOCHS
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable
import random

def plot_disparity_static(imgL, imgR, disp_true, model, focal_length, baseline):
    model.eval()
    if cuda_available:
        imgL = imgL.cuda()
        imgR = imgR.cuda()

    with torch.no_grad():
        pred_disp = model(imgL, imgR)

    pred_disp = pred_disp.squeeze().cpu().numpy()
    
    fig, axes = plt.subplots(3, 1, figsize=(10, 10))
    
    # Show Left Image
    axes[0].imshow(imgL.squeeze().permute(1, 2, 0).cpu().numpy())
    axes[0].set_title("Left Image")
    axes[0].axis('off')

    # Show Ground Truth Disparity
    axes[1].imshow(disp_true.squeeze().cpu().numpy(), cmap='plasma')
    axes[1].set_title("Ground Truth Disparity")
    axes[1].axis('off')
    
    # Show Predicted Disparity
    im = axes[2].imshow(pred_disp, cmap='plasma')
    axes[2].set_title("Predicted Disparity with Distance Legend")
    axes[2].axis('off')
    
    # Get the min and max disparity from the prediction to set the colorbar range
    min_disp = np.percentile(pred_disp[pred_disp > 0], 5) 
    max_disp = np.percentile(pred_disp, 95)
    
    cbar = fig.colorbar(im, ax=axes[2], orientation='horizontal', fraction=0.046, pad=0.04)
    cbar.set_label('Disparity Value')
    ticks = cbar.get_ticks()
    
    # Calculate the corresponding distances and create new labels
    distance_labels = []
    for disp_val in ticks:
        if disp_val > 0:
            distance = (focal_length * baseline) / disp_val
            distance_labels.append(f'{distance:.1f}m')
        else:
            distance_labels.append('Inf') # Infinite distance for zero disparity
            
    cbar.ax.set_xticklabels(distance_labels)

    plt.show()

# FOR EPOCH 3
FOCAL_LENGTH = 721 
BASELINE = 0.54 

if model_name == 'stackhourglass':
    model = stackhourglass(maxdisp)
else:
    model = basic(maxdisp)
    
if cuda_available:
    model = nn.DataParallel(model)
    model.cuda()
    
state_dict = torch.load('./best_checkpoint.tar')
model.load_state_dict(state_dict['state_dict'])

# Get a batch of test data
imgL, imgR, disp_L = next(iter(TestImgLoader))

# Pick a random index from this batch
rand_idx = random.randint(0, imgL.size(0) - 1)

# Plot for that random image
plot_disparity_static(
    imgL[rand_idx].unsqueeze(0), 
    imgR[rand_idx].unsqueeze(0), 
    disp_L[rand_idx].unsqueeze(0), 
    model,
    focal_length=FOCAL_LENGTH,
    baseline=BASELINE
)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# /tmp/ipykernel_325359/3835967028.py:58: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
# TRAINING LOOP FOR 5 EPOCHS
start_full_time = time.time()

for epoch in range(start_epoch, epochs + 1):
    total_train_loss = 0
    total_test_loss = 0

    ## Training ##
    for batch_idx, (imgL_crop, imgR_crop, disp_crop_L) in enumerate(TrainImgLoader):
        start_time = time.time()
        loss = train(imgL_crop, imgR_crop, disp_crop_L)
        print(f'Epoch {epoch}, Iter {batch_idx} training loss = {loss:.3f}, time = {(time.time() - start_time):.2f}')
        total_train_loss += loss
    print(f'epoch {epoch} total training loss = {total_train_loss / len(TrainImgLoader):.3f}')

    ## Validation ##
    for batch_idx, (imgL, imgR, disp_L) in enumerate(TestImgLoader):
        test_loss = test(imgL, imgR, disp_L)
        print(f'Iter {batch_idx} validation loss = {test_loss:.3f}')
        total_test_loss += test_loss
    
    avg_test_loss = total_test_loss / len(TestImgLoader)
    print(f'epoch {epoch} total validation loss = {avg_test_loss:.3f}')

    # Save best checkpoint
    if avg_test_loss < best_val_loss:
        best_val_loss = avg_test_loss
        savefilename = os.path.join(savemodel, 'best_checkpoint5.tar')
        torch.save({
            'epoch': epoch,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict(), 
            'train_loss': total_train_loss / len(TrainImgLoader),
            'test_loss': avg_test_loss,
        }, savefilename)
        print(f"Saved best model at epoch {epoch} with validation loss {avg_test_loss:.3f}")

print('Full training time = %.2f HR' % ((time.time() - start_full_time) / 3600))
# Out:
# /home/prath_linux/anaconda3/envs/cnn/lib/python3.10/site-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Epoch 4, Iter 0 training loss = 23.675, time = 29.14
# Epoch 4, Iter 1 training loss = 11.063, time = 24.82
# Epoch 4, Iter 2 training loss = 13.306, time = 23.45
# Epoch 4, Iter 3 training loss = 21.481, time = 25.05
# Epoch 4, Iter 4 training loss = 15.932, time = 25.20
# Epoch 4, Iter 5 training loss = 14.322, time = 24.90
# Epoch 4, Iter 6 training loss = 18.880, time = 23.38
# Epoch 4, Iter 7 training loss = 19.900, time = 24.91
# Epoch 4, Iter 8 training loss = 14.548, time = 24.95
# Epoch 4, Iter 9 training loss = 16.239, time = 25.01
# Epoch 4, Iter 10 training loss = 13.160, time = 23.45
# Epoch 4, Iter 11 training loss = 17.243, time = 25.01
# Epoch 4, Iter 12 training loss = 14.791, time = 24.93
# Epoch 4, Iter 13 training loss = 12.808, time = 23.33
# Epoch 4, Iter 14 training loss = 15.751, time = 23.43
# Epoch 4, Iter 15 training loss = 12.379, time = 23.72
# Epoch 4, Iter 16 training loss = 11.304, time = 21.84
# Epoch 4, Iter 17 training loss = 11.870, time = 23.51
# Epoch 4, Iter 18 training loss = 10.805, time = 23.54
# Epoch 4, Iter 19 training loss = 10.310, time = 23.51
# Epoch 4, Iter 20 training loss = 13.503, time = 21.88
# Epoch 4, Iter 21 training loss = 10.224, time = 23.52
# Epoch 4, Iter 22 training loss = 9.202, time = 23.50
# Epoch 4, Iter 23 training loss = 10.173, time = 21.78
# Epoch 4, Iter 24 training loss = 9.663, time = 23.63
# Epoch 4, Iter 25 training loss = 9.922, time = 23.52
# Epoch 4, Iter 26 training loss = 10.498, time = 21.84
# Epoch 4, Iter 27 training loss = 11.606, time = 23.56
# Epoch 4, Iter 28 training loss = 8.548, time = 23.50
# Epoch 4, Iter 29 training loss = 10.469, time = 21.83
# Epoch 4, Iter 30 training loss = 8.888, time = 23.57
# Epoch 4, Iter 31 training loss = 12.528, time = 23.55
# Epoch 4, Iter 32 training loss = 10.369, time = 21.78
# Epoch 4, Iter 33 training loss = 8.370, time = 23.56
# Epoch 4, Iter 34 training loss = 14.910, time = 24.74
# Epoch 4, Iter 35 training loss = 10.423, time = 23.28
# Epoch 4, Iter 36 training loss = 9.811, time = 25.24
# Epoch 4, Iter 37 training loss = 8.472, time = 25.15
# Iter 26 validation loss = 2.170
# Iter 27 validation loss = 1.552
# Iter 28 validation loss = 1.755
# Iter 29 validation loss = 1.238
# Iter 30 validation loss = 1.451
# Iter 31 validation loss = 1.650
# Iter 32 validation loss = 1.388
# Iter 33 validation loss = 1.669
# Iter 34 validation loss = 1.456
# Iter 35 validation loss = 1.621
# Iter 36 validation loss = 1.792
# Iter 37 validation loss = 1.880
# Iter 38 validation loss = 1.589
# Iter 39 validation loss = 1.367
# Iter 40 validation loss = 1.880
# Iter 41 validation loss = 1.172
# Iter 42 validation loss = 1.384
# Iter 43 validation loss = 2.396
# Iter 44 validation loss = 1.769
# Iter 45 validation loss = 1.682
# Iter 46 validation loss = 1.458
# Iter 47 validation loss = 1.428
# Iter 48 validation loss = 1.689
# Iter 49 validation loss = 2.052
# Iter 50 validation loss = 2.079
# Iter 51 validation loss = 1.398
# Iter 52 validation loss = 2.768
# Iter 53 validation loss = 1.408
# Iter 54 validation loss = 1.517
# Iter 55 validation loss = 1.612
# Iter 56 validation loss = 1.659
# Iter 57 validation loss = 1.425
# Iter 58 validation loss = 1.836
# Iter 59 validation loss = 2.603
# Iter 60 validation loss = 1.740
# Iter 61 validation loss = 1.868
# Iter 62 validation loss = 1.177
# Iter 63 validation loss = 1.458
# Iter 64 validation loss = 1.208
# Iter 65 validation loss = 1.671
# Iter 66 validation loss = 1.339
# Iter 67 validation loss = 1.607
# Iter 68 validation loss = 2.676
# Iter 69 validation loss = 1.909
# Iter 70 validation loss = 1.328
# Iter 71 validation loss = 1.779
# Iter 72 validation loss = 2.263
# Iter 73 validation loss = 2.211
# Iter 74 validation loss = 1.738
# Iter 75 validation loss = 1.544
# Iter 76 validation loss = 1.509
# Iter 77 validation loss = 1.612
# Iter 78 validation loss = 1.595
# Iter 79 validation loss = 2.327
# Iter 80 validation loss = 1.800
# Iter 81 validation loss = 1.266
# Iter 82 validation loss = 1.722
# Iter 83 validation loss = 1.347
# Iter 84 validation loss = 1.481
# Iter 85 validation loss = 1.286
# Iter 86 validation loss = 1.654
# Iter 87 validation loss = 1.670
# Iter 88 validation loss = 2.059
# Iter 89 validation loss = 1.642
# Iter 90 validation loss = 1.655
# Iter 91 validation loss = 1.473
# Iter 92 validation loss = 2.067
# Iter 93 validation loss = 2.378
# Iter 94 validation loss = 1.442
# Iter 95 validation loss = 1.777
# Iter 96 validation loss = 1.485
# Iter 97 validation loss = 2.325
# Iter 98 validation loss = 1.926
# Iter 99 validation loss = 1.218
# Iter 100 validation loss = 1.990
# Iter 101 validation loss = 2.629
# Iter 102 validation loss = 1.542
# Iter 103 validation loss = 3.299
# Iter 104 validation loss = 1.608
# Iter 105 validation loss = 2.514
# Iter 106 validation loss = 1.481
# Iter 107 validation loss = 1.464
# Iter 108 validation loss = 1.743
# Iter 109 validation loss = 1.363
# Iter 110 validation loss = 2.457
# Iter 111 validation loss = 1.709
# Iter 112 validation loss = 1.792
# Iter 113 validation loss = 1.488
# epoch 4 total validation loss = 1.731
# Saved best model at epoch 4 with validation loss 1.731
# Epoch 5, Iter 204 training loss = 1.577, time = 21.11
# Epoch 5, Iter 205 training loss = 1.518, time = 23.71
# Epoch 5, Iter 206 training loss = 1.285, time = 24.01
# Epoch 5, Iter 207 training loss = 1.551, time = 21.13
# Epoch 5, Iter 208 training loss = 2.108, time = 23.70
# Epoch 5, Iter 209 training loss = 1.500, time = 24.03
# Epoch 5, Iter 210 training loss = 1.309, time = 21.14
# Epoch 5, Iter 211 training loss = 1.704, time = 23.65
# Epoch 5, Iter 212 training loss = 1.988, time = 24.02
# Epoch 5, Iter 213 training loss = 1.335, time = 21.24
# Epoch 5, Iter 214 training loss = 1.333, time = 23.63
# Epoch 5, Iter 215 training loss = 1.916, time = 23.94
# Epoch 5, Iter 216 training loss = 2.164, time = 21.51
# Epoch 5, Iter 217 training loss = 1.181, time = 23.73
# Epoch 5, Iter 218 training loss = 2.090, time = 24.56
# Epoch 5, Iter 219 training loss = 1.639, time = 23.20
# Epoch 5, Iter 220 training loss = 1.247, time = 25.16
# Epoch 5, Iter 221 training loss = 1.403, time = 25.08
# Epoch 5, Iter 222 training loss = 2.212, time = 25.13
# Epoch 5, Iter 223 training loss = 1.546, time = 23.09
# Epoch 5, Iter 224 training loss = 1.427, time = 25.17
# Epoch 5, Iter 225 training loss = 1.153, time = 25.19
# Epoch 5, Iter 226 training loss = 1.411, time = 23.08
# Epoch 5, Iter 227 training loss = 3.094, time = 2.80
# epoch 5 total training loss = 2.027
# Iter 0 validation loss = 2.060
# Iter 1 validation loss = 1.309
# Iter 2 validation loss = 2.010
# Iter 3 validation loss = 1.736
# Iter 4 validation loss = 1.884
# Iter 5 validation loss = 1.717
# Iter 6 validation loss = 1.600
# Iter 7 validation loss = 1.696
# Iter 8 validation loss = 2.165
# Iter 9 validation loss = 1.527
# Iter 10 validation loss = 1.707
# Iter 11 validation loss = 1.597
# Iter 12 validation loss = 2.202
# Iter 13 validation loss = 1.464
# Iter 14 validation loss = 1.907
# Iter 15 validation loss = 1.415
# Iter 16 validation loss = 1.173
# Iter 17 validation loss = 1.997
# Iter 18 validation loss = 3.740
# Iter 19 validation loss = 1.195
# Iter 20 validation loss = 1.931
# Iter 21 validation loss = 1.916
# Iter 22 validation loss = 2.431
# Iter 23 validation loss = 2.041
# Iter 24 validation loss = 1.792
# Iter 25 validation loss = 1.612
# Iter 26 validation loss = 2.226
# Iter 27 validation loss = 1.632
# Iter 28 validation loss = 1.900
# Iter 29 validation loss = 1.336
# Iter 30 validation loss = 1.429
# Iter 31 validation loss = 1.788
# Iter 32 validation loss = 1.644
# Iter 33 validation loss = 1.621
# Iter 34 validation loss = 1.731
# Iter 35 validation loss = 1.567
# Iter 36 validation loss = 2.068
# Iter 37 validation loss = 1.810
# Iter 38 validation loss = 1.810
# Iter 39 validation loss = 1.580
# Iter 40 validation loss = 1.938
# Iter 41 validation loss = 1.296
# Iter 42 validation loss = 1.643
# Iter 43 validation loss = 2.483
# Iter 44 validation loss = 1.743
# Iter 45 validation loss = 2.023
# Iter 46 validation loss = 1.479
# Iter 47 validation loss = 1.371
# Iter 48 validation loss = 1.918
# Iter 49 validation loss = 2.343
# Iter 50 validation loss = 2.057
# Iter 51 validation loss = 1.629
# Iter 52 validation loss = 2.281
# Iter 53 validation loss = 1.502
# Iter 54 validation loss = 1.969
# Iter 55 validation loss = 1.910
# Iter 56 validation loss = 1.674
# Iter 57 validation loss = 1.859
# Iter 58 validation loss = 1.661
# Iter 59 validation loss = 1.992
# Iter 60 validation loss = 2.214
# Iter 61 validation loss = 2.056
# Iter 62 validation loss = 1.538
# Iter 63 validation loss = 1.741
# Iter 64 validation loss = 1.520
# Iter 65 validation loss = 1.618
# Iter 66 validation loss = 1.431
# Iter 67 validation loss = 1.793
# Iter 68 validation loss = 2.780
# Iter 69 validation loss = 2.044
# Iter 70 validation loss = 1.924
# Iter 71 validation loss = 2.085
# Iter 72 validation loss = 2.816
# Iter 73 validation loss = 2.186
# Iter 74 validation loss = 2.064
# Iter 75 validation loss = 1.754
# Iter 76 validation loss = 1.662
# Iter 77 validation loss = 1.628
# Iter 78 validation loss = 1.613
# Iter 79 validation loss = 2.008
# Iter 80 validation loss = 1.669
# Iter 81 validation loss = 1.452
# Iter 82 validation loss = 1.753
# Iter 83 validation loss = 1.379
# Iter 84 validation loss = 1.656
# Iter 85 validation loss = 1.494
# Iter 86 validation loss = 1.644
# Iter 87 validation loss = 1.973
# Iter 88 validation loss = 2.233
# Iter 89 validation loss = 1.676
# Iter 90 validation loss = 1.745
# Iter 91 validation loss = 1.712
# Iter 92 validation loss = 2.479
# Iter 93 validation loss = 2.428
# Iter 94 validation loss = 1.631
# Iter 95 validation loss = 1.948
# Iter 96 validation loss = 1.509
# Iter 97 validation loss = 2.543
# Iter 98 validation loss = 1.840
# Iter 99 validation loss = 1.347
# Iter 100 validation loss = 2.023
# Iter 101 validation loss = 3.025
# Iter 102 validation loss = 1.871
# Iter 103 validation loss = 2.806
# Iter 104 validation loss = 1.659
# Iter 105 validation loss = 2.904
# Iter 106 validation loss = 1.748
# Iter 107 validation loss = 1.898
# Iter 108 validation loss = 1.859
# Iter 109 validation loss = 1.807
# Iter 110 validation loss = 2.682
# Iter 111 validation loss = 1.550
# Iter 112 validation loss = 1.788
# Iter 113 validation loss = 1.449
# epoch 5 total validation loss = 1.863
# Full training time = 3.96 HR

# %%
# TESTING FOR 5 EPOCHS
FOCAL_LENGTH = 721 
BASELINE = 0.54 

if model_name == 'stackhourglass':
    model = stackhourglass(maxdisp)
else:
    model = basic(maxdisp)
    
if cuda_available:
    model = nn.DataParallel(model)
    model.cuda()
    
state_dict = torch.load('./best_checkpoint5.tar')
model.load_state_dict(state_dict['state_dict'])

imgL, imgR, disp_L = next(iter(TestImgLoader))
rand_idx = random.randint(0, imgL.size(0) - 1)

plot_disparity_static(
    imgL[rand_idx].unsqueeze(0), 
    imgR[rand_idx].unsqueeze(0), 
    disp_L[rand_idx].unsqueeze(0), 
    model,
    focal_length=FOCAL_LENGTH,
    baseline=BASELINE
)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# /tmp/ipykernel_325359/3835967028.py:58: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
